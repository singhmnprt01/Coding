# %%
# Self-balancing BST
# 1. AVL
# 2. Red black Tree

# %% [markdown]
# ## AVL Tree

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Insertion

# %% [markdown]
# #### Case 1
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Case 2:
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Case 3:
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Case 4:
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Summary:
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Insertion vs Deletion:

# %% [markdown]
# ## Red-black Tree

# %%
# !pip install bintrees

# %%
from bintrees import AVLTree, FastAVLTree

# %%
tree = AVLTree()

# %%
tree.insert(5,'a')

# %%
tree
# Out:
# AVLTree({5: 'a'})
